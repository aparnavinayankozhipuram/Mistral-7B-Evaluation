# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnavinayankozhipuram/Mistral-7B-Evaluation/blob/main/copy_of_Tinyllama_Evaluation_3rd_query_4th_iteration_1st_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U langchain transformers bitsandbytes accelerate
# !pip install langchain-community
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.7/437.7 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import BitsAndBytesConfig
from langchain import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# The token `HF_TOKEN` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

model_4bit = AutoModelForCausalLM.from_pretrained(
    "TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    quantization_config=quantization_config,
    token="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", # Add this line
)
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("TinyLlama/TinyLlama-1.1B-Chat-v1.0", use_auth_token=True) # Pass use_auth_token=True here as well
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]

# %%
pipeline_inst = pipeline(
        "text-generation",
        model=model_4bit,
        tokenizer=tokenizer,
        use_cache=True,
        device_map="auto",
        max_length=2500,
        do_sample=True,
        top_k=5,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
)
# Out:
# Device set to use cuda:0

# %%
llm = HuggingFacePipeline(pipeline=pipeline_inst)
# Out:
# <ipython-input-7-dd42f6ab0e69>:1: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=pipeline_inst)

# %%
template = """[INST] You are an AI assistant that follows instruction extremely well.
Please be truthful and give direct answers
Answer the question below from context below :
{question} [/INST]
"""

# %%
def generate_response(question):
  prompt = PromptTemplate(template=template, input_variables=["question","context"])
  llm_chain = LLMChain(prompt=prompt, llm=llm)
  response = llm_chain.run({"question":question})
  return response

# %%
generate_response("Why is water considered a macronutrient even though it does not provide calories?")
# Out:
# "[INST] You are an AI assistant that follows instruction extremely well.\nPlease be truthful and give direct answers\nAnswer the question below from context below :\nWhy is water considered a macronutrient even though it does not provide calories? [/INST]\nAnswer according to: \nWater is a vital macronutrient for humans as it provides essential minerals, vitamins, and electrolytes required by the body. It is essential for maintaining body temperature and regulating body fluids, including blood pressure. Water also helps in maintaining body fluids, including blood pressure, and transporting nutrients throughout the body. Therefore, water is considered a macronutrient. Water also helps in maintaining body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is essential for human health as it provides essential minerals, vitamins, and electrolytes required for various body functions. Water is a vital macronutrient that plays a crucial role in maint
# ...

# %%
# !pip install nltk rouge-score
# !pip install scikit-learn
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=69ef275d95aa7c9842397ca67b487cd12ef010d297f6923ff81cc872b01c695e
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# ...

# %%
import nltk
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Ensure necessary NLTK data is downloaded
# The original line was: nltk.download('punkt')
nltk.download('punkt_tab') # Download punkt_tab instead of just punkt


def evaluate_rag_model(predictions, references):
    """
    Evaluate RAG model using BLEU and ROUGE scores.

    Args:
    predictions (list of str): The generated text from the RAG model.
    references (list of str): The reference ground truth text.

    Returns:
    dict: BLEU and ROUGE scores.
    """
    # BLEU score
    bleu_scores = []
    for prediction, reference in zip(predictions, references):
        reference_tokens = nltk.word_tokenize(reference.lower())
        prediction_tokens = nltk.word_tokenize(prediction.lower())

        # Use smoothing function for BLEU
        smoothie = SmoothingFunction().method1
        bleu_score = sentence_bleu([reference_tokens], prediction_tokens, smoothing_function=smoothie)
        bleu_scores.append(bleu_score)

    avg_bleu_score = sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0

    # ROUGE score
    rouge_scorer_instance = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = {'rouge1': [], 'rouge2': [], 'rougeL': []}

    for prediction, reference in zip(predictions, references):
        scores = rouge_scorer_instance.score(reference, prediction)
        rouge_scores['rouge1'].append(scores['rouge1'].fmeasure)
        rouge_scores['rouge2'].append(scores['rouge2'].fmeasure)
        rouge_scores['rougeL'].append(scores['rougeL'].fmeasure)

    avg_rouge_scores = {
        'rouge1': sum(rouge_scores['rouge1']) / len(rouge_scores['rouge1']),
        'rouge2': sum(rouge_scores['rouge2']) / len(rouge_scores['rouge2']),
        'rougeL': sum(rouge_scores['rougeL']) / len(rouge_scores['rougeL']),
    }

    # Final Results
    results = {
        'avg_bleu_score': avg_bleu_score,
        'avg_rouge1_score': avg_rouge_scores['rouge1'],
        'avg_rouge2_score': avg_rouge_scores['rouge2'],
        'avg_rougeL_score': avg_rouge_scores['rougeL'],
    }

    return results
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Example usage

predictions = [
     "Water is a vital macronutrient for humans as it provides essential minerals, vitamins, and electrolytes required by the body. It is essential for maintaining body temperature and regulating body fluids, including blood pressure. Water also helps in maintaining body fluids, including blood pressure, and transporting nutrients throughout the body. Therefore, water is considered a macronutrient. Water also helps in maintaining body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is essential for human health as it provides essential minerals, vitamins, and electrolytes required for various body functions. Water is a vital macronutrient that plays a crucial role in maintaining body fluids, transporting nutrients, and regulating body temperature. Water is an essential nutrient that helps in maintaining the body’s fluid balance. Water is considered a macronutrient for humans, as it provides essential minerals, vitamins, and electrolytes required by the body. Water is essential for maintaining body temperature and regulating body fluids. Therefore, water is considered a macronutrient. It is essential to maintain body fluid balance by providing essential minerals, vitamins, and electrolytes required by the body. Water also helps in transporting nutrients, and this is essential for maintaining proper body functions like regulation of body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is an essential macronutrient that helps in maintaining body fluid balance, providing essential minerals, vitamins, and electrolytes required by the body. Water is an essential nutrient that helps in maintaining the body's fluid balance and transporting nutrients throughout the body. Water is an essential nutrient that plays a critical role in maintaining body fluids and providing essential minerals, vitamins, and electrolytes required by the body. Water is essential for maintaining body fluid balance by providing essential minerals, vitamins, and electrolytes required by the body. Water is a macronutrient that helps in maintaining the body’s fluid balance and transporting nutrients throughout the body. Water is an essential nutrient that helps in maintaining body fluids and providing essential minerals, vitamins, and electrolytes required by the body. Water is a macronutrient that plays a vital role in maintaining body fluids, transporting nutrients throughout the body, and regulating body temperature. Water is an essential nutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is considered a macronutrient as it helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that plays a vital role in maintaining body fluids and transporting nutrients throughout the body. Water is an essential macronutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is an essential nutrient that helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is an essential macronutrient that helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that plays a crucial role in maintaining body fluid balance and transporting nutrients throughout the body.\n[INST] You are an AI assistant that follows instruction extremely well.."

]
references = ["Water is considered a macronutrient because the body requires it in large amounts, even though it does not yield calories or provide energy."

]

results = evaluate_rag_model(predictions, references)
print("Evaluation Results:")
print(f"Average BLEU Score: {results['avg_bleu_score']:.4f}")
print(f"Average ROUGE-1 Score: {results['avg_rouge1_score']:.4f}")
print(f"Average ROUGE-2 Score: {results['avg_rouge2_score']:.4f}")
print(f"Average ROUGE-L Score: {results['avg_rougeL_score']:.4f}")
# Out:
# Evaluation Results:
# Average BLEU Score: 0.0073
# Average ROUGE-1 Score: 0.0441
# Average ROUGE-2 Score: 0.0185
# Average ROUGE-L Score: 0.0441

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import numpy as np

# Function to calculate Precision, Recall, F1 Score for text comparison
def calculate_metrics(y_true, y_pred):
    """
    Calculate Precision, Recall, and F1 Score between ground truth (y_true) and model-generated (y_pred) text.

    Args:
    - y_true: list of reference text (ground truth)
    - y_pred: list of generated text (model output)

    Returns:
    - precision: Precision score
    - recall: Recall score
    - f1: F1 Score
    """
    # Tokenize and convert texts to a binary representation (1 if word exists in the text, else 0)
    y_true_tokens = [set(true.split()) for true in y_true]
    y_pred_tokens = [set(pred.split()) for pred in y_pred]

    # Flatten the sets of tokens into individual word lists for comparison
    all_words = set([word for sublist in y_true_tokens + y_pred_tokens for word in sublist])

    # Create binary vectors for precision, recall, and F1 score
    y_true_binary = [[1 if word in tokens else 0 for word in all_words] for tokens in y_true_tokens]
    y_pred_binary = [[1 if word in tokens else 0 for word in all_words] for tokens in y_pred_tokens]

    # Convert to numpy arrays for use in scikit-learn metrics
    y_true_array = np.array(y_true_binary)
    y_pred_array = np.array(y_pred_binary)

    # Calculate Precision, Recall, and F1 score using sklearn
    precision = precision_score(y_true_array, y_pred_array, average='micro')
    recall = recall_score(y_true_array, y_pred_array, average='micro')
    f1 = f1_score(y_true_array, y_pred_array, average='micro')

    return precision, recall, f1

# %%
# Example ground truth (reference) text
y_true = [
    "Water is considered a macronutrient because the body requires it in large amounts, even though it does not yield calories or provide energy."

]

# Example generated text (model output)
y_pred = [
    "Water is a vital macronutrient for humans as it provides essential minerals, vitamins, and electrolytes required by the body. It is essential for maintaining body temperature and regulating body fluids, including blood pressure. Water also helps in maintaining body fluids, including blood pressure, and transporting nutrients throughout the body. Therefore, water is considered a macronutrient. Water also helps in maintaining body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is essential for human health as it provides essential minerals, vitamins, and electrolytes required for various body functions. Water is a vital macronutrient that plays a crucial role in maintaining body fluids, transporting nutrients, and regulating body temperature. Water is an essential nutrient that helps in maintaining the body’s fluid balance. Water is considered a macronutrient for humans, as it provides essential minerals, vitamins, and electrolytes required by the body. Water is essential for maintaining body temperature and regulating body fluids. Therefore, water is considered a macronutrient. It is essential to maintain body fluid balance by providing essential minerals, vitamins, and electrolytes required by the body. Water also helps in transporting nutrients, and this is essential for maintaining proper body functions like regulation of body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is an essential macronutrient that helps in maintaining body fluid balance, providing essential minerals, vitamins, and electrolytes required by the body. Water is an essential nutrient that helps in maintaining the body's fluid balance and transporting nutrients throughout the body. Water is an essential nutrient that plays a critical role in maintaining body fluids and providing essential minerals, vitamins, and electrolytes required by the body. Water is essential for maintaining body fluid balance by providing essential minerals, vitamins, and electrolytes required by the body. Water is a macronutrient that helps in maintaining the body’s fluid balance and transporting nutrients throughout the body. Water is an essential nutrient that helps in maintaining body fluids and providing essential minerals, vitamins, and electrolytes required by the body. Water is a macronutrient that plays a vital role in maintaining body fluids, transporting nutrients throughout the body, and regulating body temperature. Water is an essential nutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is considered a macronutrient as it helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that plays a vital role in maintaining body fluids and transporting nutrients throughout the body. Water is an essential macronutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is an essential nutrient that helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is an essential macronutrient that helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that plays a crucial role in maintaining body fluid balance and transporting nutrients throughout the body.\n[INST] You are an AI assistant that follows instruction extremely well.."

]

precision, recall, f1 = calculate_metrics(y_true, y_pred)

# Calculate Precision, Recall, and F1 Score#
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Precision: 0.1111
# Recall: 0.4091
# F1 Score: 0.1748

# %%
# !pip install bert-score
import bert_score

# Reference and generated sentences
reference = ["Water is considered a macronutrient because the body requires it in large amounts, even though it does not yield calories or provide energy."]

generated = ["Water is a vital macronutrient for humans as it provides essential minerals, vitamins, and electrolytes required by the body. It is essential for maintaining body temperature and regulating body fluids, including blood pressure. Water also helps in maintaining body fluids, including blood pressure, and transporting nutrients throughout the body. Therefore, water is considered a macronutrient. Water also helps in maintaining body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is essential for human health as it provides essential minerals, vitamins, and electrolytes required for various body functions. Water is a vital macronutrient that plays a crucial role in maintaining body fluids, transporting nutrients, and regulating body temperature. Water is an essential nutrient that helps in maintaining the body’s fluid balance. Water is considered a macronutrient for humans, as it provides essential minerals, vitamins, and electrolytes required by the body. Water is essential for maintaining body temperature and regulating body fluids. Therefore, water is considered a macronutrient. It is essential to maintain body fluid balance by providing essential minerals, vitamins, and electrolytes required by the body. Water also helps in transporting nutrients, and this is essential for maintaining proper body functions like regulation of body temperature, transporting nutrients throughout the body, and regulating body fluids. Water is an essential macronutrient that helps in maintaining body fluid balance, providing essential minerals, vitamins, and electrolytes required by the body. Water is an essential nutrient that helps in maintaining the body's fluid balance and transporting nutrients throughout the body. Water is an essential nutrient that plays a critical role in maintaining body fluids and providing essential minerals, vitamins, and electrolytes required by the body. Water is essential for maintaining body fluid balance by providing essential minerals, vitamins, and electrolytes required by the body. Water is a macronutrient that helps in maintaining the body’s fluid balance and transporting nutrients throughout the body. Water is an essential nutrient that helps in maintaining body fluids and providing essential minerals, vitamins, and electrolytes required by the body. Water is a macronutrient that plays a vital role in maintaining body fluids, transporting nutrients throughout the body, and regulating body temperature. Water is an essential nutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is considered a macronutrient as it helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that plays a vital role in maintaining body fluids and transporting nutrients throughout the body. Water is an essential macronutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is an essential nutrient that helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that provides essential minerals, vitamins, and electrolytes required by the body. Water is an essential macronutrient that helps in maintaining body fluid balance, providing essential minerals, and electrolytes required by the body. Water is an essential nutrient that plays a crucial role in maintaining body fluid balance and transporting nutrients throughout the body.\n[INST] You are an AI assistant that follows instruction extremely well.."]

# Compute BERTScore
P, R, F1 = bert_score.score(generated, reference, lang="en")

# Print Precision, Recall, F1-score
print(f"Precision: {P.mean():.4f}")
print(f"Recall: {R.mean():.4f}")
print(f"F1-score: {F1.mean():.4f}")
# Out:
# ...
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Precision: 0.7613
# Recall: 0.8512
# F1-score: 0.8037
