# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnavinayankozhipuram/Mistral-7B-Evaluation/blob/main/Llama_3_1_8B_Evaluation_3rd_query_1st_iteration_1st_prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U langchain transformers bitsandbytes accelerate
# !pip install langchain-community
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 543.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers torch accelerate bitsandbytes

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline

# %%
import torch
from transformers import BitsAndBytesConfig
from langchain import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible): Traceback (most recent call last):
#   File "/usr/local/bin/huggingface-cli", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/huggingface_cli.py", line 57, in main
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)

model_4bit = AutoModelForCausalLM.from_pretrained(
    "NousResearch/Hermes-3-Llama-3.1-8B",
    quantization_config=quantization_config,
    token="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", # Add this line
)
# Out:
# config.json:   0%|          | 0.00/883 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("NousResearch/Hermes-3-Llama-3.1-8B", use_auth_token=True) # Pass use_auth_token=True here as well
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:902: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/444 [00:00<?, ?B/s]

# %%
pipeline_inst = pipeline(
        "text-generation",
        model=model_4bit,
        tokenizer=tokenizer,
        use_cache=True,
        device_map="auto",
        max_length=2500,
        do_sample=True,
        top_k=5,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
)
# Out:
# Device set to use cuda:0

# %%
model_4bit
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
# ...

# %%
# !pip install langchain-community

# %%
from langchain import HuggingFacePipeline
llm = HuggingFacePipeline(pipeline=pipeline_inst)
# Out:
# <ipython-input-12-1f27993b2cd8>:2: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=pipeline_inst)

# %%
template = """[INST] You are an AI assistant that follows instruction extremely well.
Please be truthful and give direct answers
Answer the question below from context below :
{question} [/INST]
"""

# %%
# Import necessary classes before defining the function
from langchain import PromptTemplate, LLMChain
from langchain import HuggingFacePipeline # Make sure HuggingFacePipeline is also available if used

# The 'template' variable should be defined before this function is called.
# If 'template' is defined in a separate cell, ensure that cell is run first.
def generate_response(question):
  # The 'template' variable is assumed to be defined in a previous cell.
  # The 'llm' variable is assumed to be defined in a previous cell.
  prompt = PromptTemplate(template=template, input_variables=["question"]) # Removed 'context' as it's not in the template
  llm_chain = LLMChain(prompt=prompt, llm=llm)
  response = llm_chain.run({"question": question})
  return response

# %%
generate_response("Why is water considered a macronutrient even though it does not provide calories?")
# Out:
# <ipython-input-14-fbd24a3c7879>:11: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(prompt=prompt, llm=llm)
# <ipython-input-14-fbd24a3c7879>:12: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm_chain.run({"question": question})
# ...

# %%
# !pip install nltk rouge-score
# !pip install scikit-learn
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=3bbbd60c4922475b2d0f83ae60712acce9ff2cb44bb9d483e9ce38a4acd5cb05
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# ...

# %%
import nltk
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Ensure necessary NLTK data is downloaded
# The original line was: nltk.download('punkt')
nltk.download('punkt_tab') # Download punkt_tab instead of just punkt


def evaluate_rag_model(predictions, references):
    """
    Evaluate RAG model using BLEU and ROUGE scores.

    Args:
    predictions (list of str): The generated text from the RAG model.
    references (list of str): The reference ground truth text.

    Returns:
    dict: BLEU and ROUGE scores.
    """
    # BLEU score
    bleu_scores = []
    for prediction, reference in zip(predictions, references):
        reference_tokens = nltk.word_tokenize(reference.lower())
        prediction_tokens = nltk.word_tokenize(prediction.lower())

        # Use smoothing function for BLEU
        smoothie = SmoothingFunction().method1
        bleu_score = sentence_bleu([reference_tokens], prediction_tokens, smoothing_function=smoothie)
        bleu_scores.append(bleu_score)

    avg_bleu_score = sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0

    # ROUGE score
    rouge_scorer_instance = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = {'rouge1': [], 'rouge2': [], 'rougeL': []}

    for prediction, reference in zip(predictions, references):
        scores = rouge_scorer_instance.score(reference, prediction)
        rouge_scores['rouge1'].append(scores['rouge1'].fmeasure)
        rouge_scores['rouge2'].append(scores['rouge2'].fmeasure)
        rouge_scores['rougeL'].append(scores['rougeL'].fmeasure)

    avg_rouge_scores = {
        'rouge1': sum(rouge_scores['rouge1']) / len(rouge_scores['rouge1']),
        'rouge2': sum(rouge_scores['rouge2']) / len(rouge_scores['rouge2']),
        'rougeL': sum(rouge_scores['rougeL']) / len(rouge_scores['rougeL']),
    }

    # Final Results
    results = {
        'avg_bleu_score': avg_bleu_score,
        'avg_rouge1_score': avg_rouge_scores['rouge1'],
        'avg_rouge2_score': avg_rouge_scores['rouge2'],
        'avg_rougeL_score': avg_rouge_scores['rougeL'],
    }

    return results
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Example usage

predictions = [
     "Water is essential for life, and while it is not a source of calories like carbohydrates, proteins, and fats, it is still considered a macronutrient. This is because our bodies require relatively large amounts of water to function properly. Water is involved in numerous physiological processes, such as regulating body temperature, transporting nutrients and waste products, and maintaining the balance of electrolytes. Although water does not provide calories, it plays a vital role in our overall health and well-being. [/CONTEXT]\n\n[INST] Water is considered a macronutrient because our bodies require large amounts of it to function properly, and it plays a vital role in various physiological processes, even though it does not provide calories. [/INST]://INST://INST\n://INST://INST\n://INST\n[INST]Water is considered a macronutrient because it is essential for various physiological processes and our body needs relatively large amounts of it to function properly. Although it does not provide calories, its importance in maintaining overall health and well-being is vital. [/INST]://INST\n://INST\n://INST\n[INST]Water is considered a macronutrient because it is necessary for many essential physiological processes and our bodies require significant amounts of it to function properly. Although it does not provide calories, its importance for overall health is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because it is essential for many physiological processes and we need large amounts of it to function properly. Even though it does not provide calories, its importance to our overall well-being is vital. [/INST]://INST\n[INST]Water is considered a macronutrient because it is required in large amounts for our body to function properly. Although it doesn't provide calories, its role in maintaining our health and well-being is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because our bodies need it in significant amounts for proper functioning, despite it not providing calories. Its importance to our overall health is vital. [/INST]://INST\n[INST]Water is considered a macronutrient because it is required in large amounts for our bodies to function properly, even though it does not provide calories. Its importance in maintaining our health and well-being is essential. [/INST]://INST\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not offer calories. The importance of water to our overall health is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because we require it in large amounts to function properly, even though it does not provide calories. Its significance for our health and well-being is vital. [/INST]://the\n[INST]Water is considered a macronutrient because our bodies need large amounts of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require it in large amounts for proper functioning, even though it does not provide calories. The importance of water to our health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, despite it not providing calories. Its significance for our overall health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The importance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. Its significance for our health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not provide calories. The importance of water to our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not offer calories. Its significance for our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, despite it not providing calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide.  "

]
references = ["Water is considered a macronutrient because the body requires it in large amounts, even though it does not yield calories or provide energy.."

]

results = evaluate_rag_model(predictions, references)
print("Evaluation Results:")
print(f"Average BLEU Score: {results['avg_bleu_score']:.4f}")
print(f"Average ROUGE-1 Score: {results['avg_rouge1_score']:.4f}")
print(f"Average ROUGE-2 Score: {results['avg_rouge2_score']:.4f}")
print(f"Average ROUGE-L Score: {results['avg_rougeL_score']:.4f}")
# Out:
# Evaluation Results:
# Average BLEU Score: 0.0053
# Average ROUGE-1 Score: 0.0215
# Average ROUGE-2 Score: 0.0151
# Average ROUGE-L Score: 0.0215

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix
import numpy as np

# Function to calculate Precision, Recall, F1 Score for text comparison
def calculate_metrics(y_true, y_pred):
    """
    Calculate Precision, Recall, and F1 Score between ground truth (y_true) and model-generated (y_pred) text.

    Args:
    - y_true: list of reference text (ground truth)
    - y_pred: list of generated text (model output)

    Returns:
    - precision: Precision score
    - recall: Recall score
    - f1: F1 Score
    """
    # Tokenize and convert texts to a binary representation (1 if word exists in the text, else 0)
    y_true_tokens = [set(true.split()) for true in y_true]
    y_pred_tokens = [set(pred.split()) for pred in y_pred]

    # Flatten the sets of tokens into individual word lists for comparison
    all_words = set([word for sublist in y_true_tokens + y_pred_tokens for word in sublist])

    # Create binary vectors for precision, recall, and F1 score
    y_true_binary = [[1 if word in tokens else 0 for word in all_words] for tokens in y_true_tokens]
    y_pred_binary = [[1 if word in tokens else 0 for word in all_words] for tokens in y_pred_tokens]

    # Convert to numpy arrays for use in scikit-learn metrics
    y_true_array = np.array(y_true_binary)
    y_pred_array = np.array(y_pred_binary)

    # Calculate Precision, Recall, and F1 score using sklearn
    precision = precision_score(y_true_array, y_pred_array, average='micro')
    recall = recall_score(y_true_array, y_pred_array, average='micro')
    f1 = f1_score(y_true_array, y_pred_array, average='micro')

    return precision, recall, f1

# %%
# Example ground truth (reference) text
y_true = [
    "Water is considered a macronutrient because the body requires it in large amounts, even though it does not yield calories or provide energy.."

]

# Example generated text (model output)
y_pred = [
    "Water is essential for life, and while it is not a source of calories like carbohydrates, proteins, and fats, it is still considered a macronutrient. This is because our bodies require relatively large amounts of water to function properly. Water is involved in numerous physiological processes, such as regulating body temperature, transporting nutrients and waste products, and maintaining the balance of electrolytes. Although water does not provide calories, it plays a vital role in our overall health and well-being. [/CONTEXT]\n\n[INST] Water is considered a macronutrient because our bodies require large amounts of it to function properly, and it plays a vital role in various physiological processes, even though it does not provide calories. [/INST]://INST://INST\n://INST://INST\n://INST\n[INST]Water is considered a macronutrient because it is essential for various physiological processes and our body needs relatively large amounts of it to function properly. Although it does not provide calories, its importance in maintaining overall health and well-being is vital. [/INST]://INST\n://INST\n://INST\n[INST]Water is considered a macronutrient because it is necessary for many essential physiological processes and our bodies require significant amounts of it to function properly. Although it does not provide calories, its importance for overall health is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because it is essential for many physiological processes and we need large amounts of it to function properly. Even though it does not provide calories, its importance to our overall well-being is vital. [/INST]://INST\n[INST]Water is considered a macronutrient because it is required in large amounts for our body to function properly. Although it doesn't provide calories, its role in maintaining our health and well-being is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because our bodies need it in significant amounts for proper functioning, despite it not providing calories. Its importance to our overall health is vital. [/INST]://INST\n[INST]Water is considered a macronutrient because it is required in large amounts for our bodies to function properly, even though it does not provide calories. Its importance in maintaining our health and well-being is essential. [/INST]://INST\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not offer calories. The importance of water to our overall health is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because we require it in large amounts to function properly, even though it does not provide calories. Its significance for our health and well-being is vital. [/INST]://the\n[INST]Water is considered a macronutrient because our bodies need large amounts of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require it in large amounts for proper functioning, even though it does not provide calories. The importance of water to our health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, despite it not providing calories. Its significance for our overall health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The importance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. Its significance for our health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not provide calories. The importance of water to our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not offer calories. Its significance for our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, despite it not providing calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide."

]

precision, recall, f1 = calculate_metrics(y_true, y_pred)

# Calculate Precision, Recall, and F1 Score#
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Precision: 0.1667
# Recall: 0.7727
# F1 Score: 0.2742

# %%
# !pip install bert-score
import bert_score

# Reference and generated sentences
reference = ["Water is considered a macronutrient because the body requires it in large amounts, even though it does not yield calories or provide energy."]

generated = ["Water is essential for life, and while it is not a source of calories like carbohydrates, proteins, and fats, it is still considered a macronutrient. This is because our bodies require relatively large amounts of water to function properly. Water is involved in numerous physiological processes, such as regulating body temperature, transporting nutrients and waste products, and maintaining the balance of electrolytes. Although water does not provide calories, it plays a vital role in our overall health and well-being. [/CONTEXT]\n\n[INST] Water is considered a macronutrient because our bodies require large amounts of it to function properly, and it plays a vital role in various physiological processes, even though it does not provide calories. [/INST]://INST://INST\n://INST://INST\n://INST\n[INST]Water is considered a macronutrient because it is essential for various physiological processes and our body needs relatively large amounts of it to function properly. Although it does not provide calories, its importance in maintaining overall health and well-being is vital. [/INST]://INST\n://INST\n://INST\n[INST]Water is considered a macronutrient because it is necessary for many essential physiological processes and our bodies require significant amounts of it to function properly. Although it does not provide calories, its importance for overall health is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because it is essential for many physiological processes and we need large amounts of it to function properly. Even though it does not provide calories, its importance to our overall well-being is vital. [/INST]://INST\n[INST]Water is considered a macronutrient because it is required in large amounts for our body to function properly. Although it doesn't provide calories, its role in maintaining our health and well-being is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because our bodies need it in significant amounts for proper functioning, despite it not providing calories. Its importance to our overall health is vital. [/INST]://INST\n[INST]Water is considered a macronutrient because it is required in large amounts for our bodies to function properly, even though it does not provide calories. Its importance in maintaining our health and well-being is essential. [/INST]://INST\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not offer calories. The importance of water to our overall health is crucial. [/INST]://INST\n[INST]Water is considered a macronutrient because we require it in large amounts to function properly, even though it does not provide calories. Its significance for our health and well-being is vital. [/INST]://the\n[INST]Water is considered a macronutrient because our bodies need large amounts of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require it in large amounts for proper functioning, even though it does not provide calories. The importance of water to our health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, despite it not providing calories. Its significance for our overall health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The importance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. Its significance for our health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not provide calories. The importance of water to our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not offer calories. Its significance for our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, despite it not providing calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function properly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function correctly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function properly, even though it does not provide calories. The importance of water to our overall health is crucial. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need significant amounts of it to function correctly, even though it does not offer calories. Its role in our health is vital. [/INST]the\n[INST]Water is considered a macronutrient because our bodies need large quantities of it to function properly, even though it does not provide calories. The significance of water to our health is essential. [/INST]the\n[INST]Water is considered a macronutrient because our bodies require large amounts of it to function correctly, even though it does not provide."]

# Compute BERTScore
P, R, F1 = bert_score.score(generated, reference, lang="en")

# Print Precision, Recall, F1-score
print(f"Precision: {P.mean():.4f}")
print(f"Recall: {R.mean():.4f}")
print(f"F1-score: {F1.mean():.4f}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.5 MB/s eta 0:00:00
# ...
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# ...
